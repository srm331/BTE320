# %% [markdown]
# <a href="https://colab.research.google.com/github/srm331/BTE320/blob/main/In_Class_AssignmentsBTE320.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
sales = float(input("Enter sales value ($): "))

cogs = 0.4 * sales
gross_profit = sales - cogs

print(f"Sales: {sales}$")
print(f"Cost of Goods Sold: {cogs}$")
print(f"Gross Profit: {gross_profit}$")

taxes = float(input("Taxes ($): "))
Net_Income = float(input("Net Income ($): "))
net_income = gross_profit - taxes

print(f"Net income: {net_income}$")
# Out:
# Enter sales value ($): 3
# Sales: 3.0$
# Cost of Goods Sold: 1.2000000000000002$
# Gross Profit: 1.7999999999999998$
# Taxes ($): 5
# Net Income ($): 3000
# Net income: -3.2$

# %%
num = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))
op = (input("Numerical operation (eg., +, -, etc.): "))

if op == "+":
    res = num + num2
elif op == "-":
    res = num - num2
elif op == "*":
    res = num * num2
elif op == "/":
    res = num / num2
elif op == "//":
    res = num // num2
elif op == "**":
    res = num ** num2
elif op == "%":
    res = num % num2
else:
    print("Invalid operation")

print(f"Result: {res}")
# Out:
# Enter the first number: 7
# Enter the second number: 8
# Numerical operation (eg., +, -, etc.): *
# Result: 56.0

# %%
sales = float(input("Enter sales value ($): "))
tax_rate = float(input("Enter tax rate (%): "))


cogs = 0.4 * sales
gross_profit = sales - cogs
taxes = gross_profit * tax_rate / 100
net_income = gross_profit - taxes

print(f"Sales: {sales}$")
print(f"Cost of Goods Sold: {cogs}$")
print(f"Gross Profit: {gross_profit}$")
print(f"Taxes: {taxes}$")
print(f"Net income: {net_income}$")
# Out:
# Enter sales value ($): 12000
# Enter tax rate (%): 30
# Sales: 12000.0$
# Cost of Goods Sold: 4800.0$
# Gross Profit: 7200.0$
# Taxes: 2160.0$
# Net income: 5040.0$

# %%
for variable in sequence:

# %%
print("Hour Fee")
for hour in range(1,9):
  fee = 5 + 2.5 * hour
  if fee < 10.0:
    fee = 10.0
  elif fee > 20.0:
    fee = 20.0
  print(f"{hour}   {fee}")
# Out:
# Hour Fee
# 1   10.0
# 2   10.0
# 3   12.5
# 4   15.0
# 5   17.5
# 6   20.0
# 7   20.0
# 8   20.0

# %%
import math

ticketPrice = 10
defaultAudience = 20

print("Ad$\tProfit")

for adMoney in range(0, 201, 25):
  revenue = (defaultAudience + 2 * round(math.sqrt(adMoney ** 0.5))) * ticketPrice
  costs = 200 + adMoney
  profit = revenue - costs
  print(f"{float(adMoney)}\t{float(profit)}")
# Out:
# Ad$	Profit
# 0.0	0.0
# 25.0	15.0
# 50.0	10.0
# 75.0	-15.0
# 100.0	-40.0
# 125.0	-65.0
# 150.0	-90.0
# 175.0	-95.0
# 200.0	-120.0
