# %% [markdown]
# <a href="https://colab.research.google.com/github/srm331/BTE320/blob/main/BTE320E_Notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
2 ** 3
# Out:
# 8

# %%
5 % 3
# Out:
# 2

# %%
3 % 4
# Out:
# 3

# %%
3.14 * (3 ** 2)
# Out:
# 28.26

# %%
interest = 3
principal = 3000
n = 1
final = principal * (1 + interest / 100) **n
print(final)
# Out:
# 3090.0

# %%
print ("Interest rate", interest, sep=" => ")
print ("Number of years:", n)
# Out:
# Interest rate => 3
# Number of years: 1

# %%
print ("Interest rate:", interest, end="---")
print ("Number of years=", n)
# Out:
# Interest rate: 3---Number of years= 1

# %%
print ("Interest rate", interest, sep=">>>", end="&&&")
print ("Number of years =", n)
# Out:
# Interest rate>>>3&&&Number of years = 1

# %%
print ("Interest rate:", interest, "; Number of years =", n)
# Out:
# Interest rate: 3 ; Number of years = 1

# %%
print ("Interest rate: {}; Number of years = {}".format(interest, n))
# Out:
# Interest rate: 3; Number of years = 1

# %%
print (f"Interest rate: {interest}; Number of years = {n}")
# Out:
# Interest rate: 3; Number of years = 1

# %%
print ("Interest rate: %.2f" % interest)
# Out:
# Interest rate: 3.00

# %%
interest = input("Set interest value (%): ")
print (interest)
type(interest)
# Out:
# Set interest value (%): 4
# 4
# str

# %%
interest = float(input("Set interest value (%): "))
principal = float(input("Enter initial amount on the account ($): "))
n = int(input("Enter number of years: "))

final = principal * (1 + interest / 100) **n

print (f"Final amount after {n} year(s): ${final}$")
# Out:
# Set interest value (%): 3
# Enter initial amount on the account ($): 30
# Enter number of years: 300
# Final amount after 300 year(s): $212955.40447852903$

# %% [markdown]
# Week 3

# %%
email = "Open this link: http://www.spam.org to receive your award!!!"
is_urgent = "URGENT"
has_www = "www."

if is_urgent in email:
  print("Phissing!")
elif has_www in email:
  print("Spam!")
else:
  print("Legit")
# Out:
# Spam!

# %%
if condition
  exprs
  exprs
elif another_condition
  exprs
  exprs

# %%
grade = float(input("Enter your grade (0-100): "))

if grade >= 97:
  print("A+")
if grade >= 93:
  print("A")
# Out:
# Enter your grade (0-100): 93
# A

# %%
if cond1:
  if cond2:
    exprs

# %%
email = " URGENT!! Click on the following: to ..."
is_urgent = "URGENT"
has_www = "www."

if is_urgent in email:
  if has_www in email:
    print("Phising!")
  else:
    print("Spam!")
else:
    print("Legit")
# Out:
# Spam!

# %%
email = " URGENT!! Click on the following: to ..."
is_urgent = "URGENT"
has_www = "www."

if is_urgent in email and has_www in email:
  print("Phising!")
elif is_urgent in email:
  print("Spam!")
else:
  print("Legit")
# Out:
# Spam!

# %%
x = 3

if x % 2 == 0:
  print(x, "is even")
else:
  print(x, "is odd")
# Out:
# 3 is odd

# %%
print("Even" if x % 2 == 0 else "Odd")
# Out:
# Odd

# %% [markdown]
# Week 5

# %%
check = input("Print greeting (y/n)? ")
while check == 'y':
  name = input('Enter a name: ')
  print(f"Hello, {name}!")
  check = input("Do you want to continue (y/n)? ")
# Out:
# Print greeting (y/n)? y
# Enter a name: Sam
# Hello, Sam!
# Do you want to continue (y/n)? y
# Enter a name: Sam
# Hello, Sam!
# Do you want to continue (y/n)? Yes

# %%
stop = 0
while True:
  print("This will run forever", stop)
  if stop == 5:
    break
  stop += 1
print(stop)
# Out:
# This will run forever 0
# This will run forever 1
# This will run forever 2
# This will run forever 3
# This will run forever 4
# This will run forever 5
# 5

# %%
for i in range(5):
  if i == 3:
    continue
  print(i)
# Out:
# 0
# 1
# 2
# 4

# %%
def func(i1, i2,):
  expr
  expr
  return result

# %%
def addFunc (a, b):
  c = a + b
  return c

# %%
def avg(a,b,l=[]):
  return a(1) + b(1)

res = avg(sum, len)
print(res)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_263/294918272.py in <cell line: 0>()
#       2   return a(1) + b(1)
#       3
# ----> 4 res = avg(sum, len)
#       5 print(res)
#
# /tmp/ipykernel_263/294918272.py in avg(a, b, l)
#       1 def avg(a,b,l=[]):
# ----> 2   return a(1) + b(1)
#       3
#       4 res = avg(sum, len)
#       5 print(res)
#
# TypeError: 'int' object is not iterable
